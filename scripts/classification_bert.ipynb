# %% [markdown]
# BERT classification of event categories

# %% [markdown]
# # Imports and Installations

# %%
# pip install simpletransformers
# Out:
# Collecting simpletransformers
#   Using cached simpletransformers-0.70.1-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: numpy in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from simpletransformers) (1.24.3)
# Requirement already satisfied: requests in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from simpletransformers) (2.31.0)
# Requirement already satisfied: tqdm>=4.47.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from simpletransformers) (4.65.0)
# Collecting regex (from simpletransformers)
#   Using cached regex-2024.5.15-cp311-cp311-macosx_10_9_x86_64.whl.metadata (40 kB)
# Collecting transformers>=4.31.0 (from simpletransformers)
#   Downloading transformers-4.42.3-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 786.3 kB/s eta 0:00:00 0:00:01
# Collecting datasets (from simpletransformers)
#   Using cached datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scipy in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from simpletransformers) (1.10.1)
# Requirement already satisfied: scikit-learn in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from simpletransformers) (1.4.1.post1)
# Collecting seqeval (from simpletransformers)
#   Using cached seqeval-1.2.2-py3-none-any.whl
# Collecting tensorboard (from simpletransformers)
#   Using cached tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorboardx (from simpletransformers)
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from simpletransformers) (2.1.4)
# Collecting tokenizers (from simpletransformers)
#   Using cached tokenizers-0.19.1-cp311-cp311-macosx_10_12_x86_64.whl.metadata (6.7 kB)
# Collecting wandb>=0.10.32 (from simpletransformers)
#   Downloading wandb-0.17.3-py3-none-macosx_10_9_x86_64.whl.metadata (10 kB)
# Collecting streamlit (from simpletransformers)
#   Using cached streamlit-1.36.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting sentencepiece (from simpletransformers)
#   Using cached sentencepiece-0.2.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (7.7 kB)
# Collecting filelock (from transformers>=4.31.0->simpletransformers)
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers>=4.31.0->simpletransformers)
#   Using cached huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from transformers>=4.31.0->simpletransformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from transformers>=4.31.0->simpletransformers) (6.0.1)
# Collecting safetensors>=0.4.1 (from transformers>=4.31.0->simpletransformers)
#   Using cached safetensors-0.4.3-cp311-cp311-macosx_10_12_x86_64.whl.metadata (3.8 kB)
# Collecting click!=8.0.0,>=7.1 (from wandb>=0.10.32->simpletransformers)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.10.32->simpletransformers)
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from wandb>=0.10.32->simpletransformers) (3.10.0)
# Collecting protobuf!=4.21.0,<6,>=3.19.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading protobuf-5.27.2-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Requirement already satisfied: psutil>=5.0.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from wandb>=0.10.32->simpletransformers) (5.9.8)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading sentry_sdk-2.7.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting setproctitle (from wandb>=0.10.32->simpletransformers)
#   Using cached setproctitle-1.3.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from wandb>=0.10.32->simpletransformers) (68.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from requests->simpletransformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from requests->simpletransformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from requests->simpletransformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from requests->simpletransformers) (2024.2.2)
# Collecting pyarrow>=15.0.0 (from datasets->simpletransformers)
#   Using cached pyarrow-16.1.0-cp311-cp311-macosx_10_15_x86_64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets->simpletransformers)
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->simpletransformers)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting requests (from simpletransformers)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.47.0 (from simpletransformers)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets->simpletransformers)
#   Using cached xxhash-3.4.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->simpletransformers)
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets->simpletransformers)
#   Using cached fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets->simpletransformers)
#   Using cached aiohttp-3.9.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from pandas->simpletransformers) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from pandas->simpletransformers) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from scikit-learn->simpletransformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from scikit-learn->simpletransformers) (2.2.0)
# Collecting altair<6,>=4.0 (from streamlit->simpletransformers)
#   Using cached altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit->simpletransformers)
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit->simpletransformers)
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from streamlit->simpletransformers) (10.2.0)
# Collecting rich<14,>=10.14.0 (from streamlit->simpletransformers)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from streamlit->simpletransformers) (8.2.2)
# Collecting toml<2,>=0.10.1 (from streamlit->simpletransformers)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from streamlit->simpletransformers) (4.10.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->simpletransformers)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from streamlit->simpletransformers) (6.3.3)
# Collecting absl-py>=0.4 (from tensorboard->simpletransformers)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->simpletransformers)
#   Using cached grpcio-1.64.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.3 kB)
# Collecting markdown>=2.6.8 (from tensorboard->simpletransformers)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.21.0,<6,>=3.19.0 (from wandb>=0.10.32->simpletransformers)
#   Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: six>1.9 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from tensorboard->simpletransformers) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->simpletransformers)
#   Using cached tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->simpletransformers)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: jinja2 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (4.21.1)
# Collecting toolz (from altair<6,>=4.0->streamlit->simpletransformers)
#   Using cached toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->simpletransformers)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from aiohttp->datasets->simpletransformers) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->simpletransformers)
#   Using cached frozenlist-1.4.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->simpletransformers)
#   Using cached multidict-6.0.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->simpletransformers)
#   Using cached yarl-1.9.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (31 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->simpletransformers)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.5)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->simpletransformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached simpletransformers-0.70.1-py3-none-any.whl (316 kB)
# Downloading transformers-4.42.3-py3-none-any.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 6.1 MB/s eta 0:00:0000:0100:01
# Using cached regex-2024.5.15-cp311-cp311-macosx_10_9_x86_64.whl (281 kB)
# Using cached tokenizers-0.19.1-cp311-cp311-macosx_10_12_x86_64.whl (2.5 MB)
# Downloading wandb-0.17.3-py3-none-macosx_10_9_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 7.3 MB/s eta 0:00:0000:0100:01
# Using cached datasets-2.20.0-py3-none-any.whl (547 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached sentencepiece-0.2.0-cp311-cp311-macosx_10_9_x86_64.whl (1.2 MB)
# Using cached streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
# Using cached tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached altair-5.3.0-py3-none-any.whl (857 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Using cached fsspec-2024.5.0-py3-none-any.whl (316 kB)
# Using cached aiohttp-3.9.5-cp311-cp311-macosx_10_9_x86_64.whl (402 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached grpcio-1.64.1-cp311-cp311-macosx_10_9_universal2.whl (10.4 MB)
# Using cached huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Using cached pyarrow-16.1.0-cp311-cp311-macosx_10_15_x86_64.whl (28.4 MB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached safetensors-0.4.3-cp311-cp311-macosx_10_12_x86_64.whl (415 kB)
# Downloading sentry_sdk-2.7.1-py2.py3-none-any.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.2/300.2 kB 4.5 MB/s eta 0:00:00:00:01
# Using cached tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Using cached setproctitle-1.3.3-cp311-cp311-macosx_10_9_x86_64.whl (11 kB)
# Using cached xxhash-3.4.1-cp311-cp311-macosx_10_9_x86_64.whl (31 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached frozenlist-1.4.1-cp311-cp311-macosx_10_9_x86_64.whl (55 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached multidict-6.0.5-cp311-cp311-macosx_10_9_x86_64.whl (30 kB)
# Using cached yarl-1.9.4-cp311-cp311-macosx_10_9_x86_64.whl (83 kB)
# Using cached toolz-0.12.1-py3-none-any.whl (56 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: sentencepiece, xxhash, werkzeug, tqdm, toolz, toml, tensorboard-data-server, smmap, setproctitle, sentry-sdk, safetensors, requests, regex, pyarrow-hotfix, pyarrow, protobuf, multidict, mdurl, markdown, grpcio, fsspec, frozenlist, filelock, docker-pycreds, dill, click, cachetools, blinker, absl-py, yarl, tensorboardx, tensorboard, pydeck, multiprocess, markdown-it-py, huggingface-hub, gitdb, aiosignal, tokenizers, seqeval, rich, gitpython, aiohttp, wandb, transformers, altair, streamlit, datasets, simpletransformers
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# Successfully installed absl-py-2.1.0 aiohttp-3.9.5 aiosignal-1.3.1 altair-5.3.0 blinker-1.8.2 cachetools-5.3.3 click-8.1.7 datasets-2.20.0 dill-0.3.8 docker-pycreds-0.4.0 filelock-3.15.4 frozenlist-1.4.1 fsspec-2024.5.0 gitdb-4.0.11 gitpython-3.1.43 grpcio-1.64.1 huggingface-hub-0.23.4 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 multidict-6.0.5 multiprocess-0.70.16 protobuf-4.25.3 pyarrow-16.1.0 pyarrow-hotfix-0.6 pydeck-0.9.1 regex-2024.5.15 requests-2.32.3 rich-13.7.1 safetensors-0.4.3 sentencepiece-0.2.0 sentry-sdk-2.7.1 seqeval-1.2.2 setproctitle-1.3.3 simpletransformers-0.70.1 smmap-5.0.1 streamlit-1.36.0 tensorboard-2.17.0 tensorboard-data-server-0.7.2 tensorboardx-2.6.2.2 tokenizers-0.19.1 toml-0.10.2 toolz-0.12.1 tqdm-4.66.4 transformers-4.42.3 wandb-0.17.3 werkzeug-3.0.3 xxhash-3.4.1 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install torch
# Out:
# Collecting torch
#   Using cached torch-2.2.2-cp311-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: filelock in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from torch) (4.10.0)
# Collecting sympy (from torch)
#   Using cached sympy-1.12.1-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from torch) (2024.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Collecting mpmath<1.4.0,>=1.1.0 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached torch-2.2.2-cp311-none-macosx_10_9_x86_64.whl (150.8 MB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.12.1-py3-none-any.whl (5.7 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, networkx, torch
# Successfully installed mpmath-1.3.0 networkx-3.3 sympy-1.12.1 torch-2.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install optuna
# Out:
# Requirement already satisfied: optuna in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (3.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from optuna) (1.8.1)
# Requirement already satisfied: colorlog in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from optuna) (5.0.1)
# Requirement already satisfied: numpy in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from optuna) (2.0.25)
# Requirement already satisfied: tqdm in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna) (4.10.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/martin/anaconda3/envs/simple_classification/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import pandas as pd
import re
from sklearn.model_selection import GroupShuffleSplit
import torch
from sklearn.metrics import mean_squared_error, f1_score, accuracy_score, classification_report, confusion_matrix
import optuna
import seaborn as sns
import matplotlib.pyplot as plt
import os
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from simpletransformers.classification import ClassificationModel, ClassificationArgs
#       2 import pandas as pd
#       3 import re
#
# File ~/anaconda3/envs/ml_basic/lib/python3.11/site-packages/simpletransformers/classification/__init__.py:1
# ----> 1 from simpletransformers.classification.classification_model import ClassificationModel
#       2 from simpletransformers.classification.multi_label_classification_model import (
#       3     MultiLabelClassificationModel,
#       4 )
#       5 from simpletransformers.classification.multi_modal_classification_model import (
#       6     MultiModalClassificationModel,
#       7 )
#
# File ~/anaconda3/envs/ml_basic/lib/python3.11/site-packages/simpletransformers/classification/classification_model.py:34
#      22 from scipy.special import softmax
#      23 from sklearn.metrics import (
#      24     confusion_matrix,
#      25     f1_score,
#    (...)
#      32     accuracy_score,
#      33 )
# ---> 34 from torch.utils.tensorboard import SummaryWriter
#      35 from torch.nn import CrossEntropyLoss
#      36 from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
#
# ModuleNotFoundError: No module named 'torch.utils'

# %%
# Check CUDA availability and set the 'use_cuda' argument accordingly
use_cuda = torch.cuda.is_available()
use_cuda
# Out:
# True

# %% [markdown]
# # Load Data

# %%
# run_in_colab = True
run_in_colab = False

# %%
if run_in_colab:

    from google.colab import drive
    drive.mount('/content/drive')

    # TODO: Change the current working directory to the location where the data folder is stored
    # %cd /content/drive/MyDrive/classification_bert/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Masterarbeit/Paper/code/classification_bert

# %%
df_train = pd.read_csv('../data/ground_truth_train.csv')
df_test = pd.read_csv('../data/ground_truth_test.csv')

# %%
df_train.shape, df_test.shape
# Out:
# ((191, 15), (74, 15))

# %%
# assert that no documents from train are in test data
set(df_train['document']).intersection(set(df_test['document']))
# Out:
# set()

# %%
df_train.head()
# Out:
#   document                                               text  \
# 0    1.txt  The diverse range of the members’ educational ...
# 1   10.txt  Contributing to society by improving access to...
# 2   10.txt  Contributing to society by improving access to...
# 3  100.txt  Our water strategy focuses on working towards ...
# 4  100.txt  Our water strategy focuses on working towards ...
#
#                                              keyword         event_trigger  \
# 0  25-74 [members’ educational and professional b...      75-83 [includes]
# 1           140-170 [Ambition Zero Carbon programme]  125-135 [delivering]
# 2                   59-83 [environmental protection]     27-36 [improving]
# 3                           119-133 [water security]     111-118 [support]
# 4                          0-18 [Our water strategy]       19-26 [focuses]
#
#   temporal_status  measurability event_factuality  kw_is_nsubj  kw_is_dobj  \
# 0         ongoing            1.0                _        False       False
# 1         ongoing            2.0            3_max        False        True
# 2         ongoing            1.0            3_max        False       False
# 3         ongoing            2.0            0_low        False        True
# 4         ongoing            1.0            3_max         True       False
#
#    kw_is_pobj   category                                         text_kw_et  \
# 0        True  situation  The diverse range of the members’ educational ...
# 1       False     action  Contributing to society by improving access to...
# 2       False     action  Contributing to society by improving access to...
# 3       False     action  Our water strategy focuses on working towards ...
# 4       False  situation  Our water strategy focuses on working towards ...
#
#                                              text_kw  \
# 0  The diverse range of the members’ educational ...
# 1  Contributing to society by improving access to...
# 2  Contributing to society by improving access to...
# 3  Our water strategy focuses on working towards ...
# 4  Our water strategy focuses on working towards ...
#
#   relation_time_specification relation_unit
# 0                         NaN           NaN
# 1                         NaN           NaN
# 2                         NaN           NaN
# 3                         NaN           NaN
# 4                         NaN           NaN

# %% [markdown]
# # Prepare Data for BERT

# %%
def extract_content_in_brackets(text):
    """
    Extracts and returns the content within the first pair of square brackets found in the given text.
    If no square brackets are found, returns an empty string.
    """
    text = str(text)
    match = re.search(r'\[(.*?)\]', text)
    if match:
        return match.group(1)
    else:
        return ""

df_train['event_trigger'] = df_train['event_trigger'].apply(extract_content_in_brackets)
df_test['event_trigger'] = df_test['event_trigger'].apply(extract_content_in_brackets)
df_train['keyword'] = df_train['keyword'].apply(extract_content_in_brackets)
df_test['keyword'] = df_test['keyword'].apply(extract_content_in_brackets)

# %%
# select relevant columns
df_train = df_train[['document', 'text', 'event_trigger', 'keyword', 'category']]
df_test = df_test[['document', 'text', 'event_trigger', 'keyword', 'category']]

# %%
def format_text(row):
    sentence = row['text'].replace(row['keyword'], f"[KEYWORD] {row['keyword']} [/KEYWORD]")
    sentence = sentence.replace(row['event_trigger'], f"[TRIGGER] {row['event_trigger']} [/TRIGGER]")
    return sentence

df_train['text'] = df_train.apply(format_text, axis=1)
df_test['text'] = df_test.apply(format_text, axis=1)

# %%
# rename "category" to "label"
df_train = df_train.rename(columns={'category': 'label'})
df_test = df_test.rename(columns={'category': 'label'})

# Map labels to integers if necessary
label_mapping = {'action': 0, 'intention': 1, 'belief': 2, 'situation': 3}  # Update according to your labels
df_train['label'] = df_train['label'].map(label_mapping)
df_test['label'] = df_test['label'].map(label_mapping)

# %%
# Select only the necessary columns
df_train = df_train[['text', 'label']]
df_test = df_test[['text', 'label']]

# %%
X_train = df_train['text']
y_train = df_train['label']
X_test = df_test['text']
y_test = df_test['label']

# %%
set(df_train['label']), set(df_test['label'])
# Out:
# ({0, 1, 2, 3}, {0, 1, 2, 3})

# %%
num_labels = len(df_train['label'].unique())
num_labels
# Out:
# 4

# %%
df_train.head()
# Out:
#                                                 text  label
# 0  The diverse range of the [KEYWORD] members’ ed...      3
# 1  Contributing to society by improving access to...      0
# 2  Contributing to society by [TRIGGER] improving...      0
# 3  Our water strategy focuses on working towards ...      0
# 4  [KEYWORD] Our water strategy [/KEYWORD] [TRIGG...      3

# %% [markdown]
# # Hyperparameter Training

# %%
# def objective(trial):
#     model_args = ClassificationArgs(
#         num_train_epochs=trial.suggest_int("num_train_epochs", 1, 5),
#         learning_rate=trial.suggest_float("learning_rate", 1e-6, 1e-4, log=True),
#         train_batch_size=trial.suggest_int("train_batch_size", 8, 32),
#         eval_batch_size=trial.suggest_int("eval_batch_size", 8, 32),
#         max_seq_length=trial.suggest_int("max_seq_length", 128, 512),
#         overwrite_output_dir=True,
#         save_steps=-1,  # Disable checkpoint saving
#         save_model_every_epoch=False  # Disable model saving every epoch
#     )

#     # Create a ClassificationModel
#     model = ClassificationModel(
#         "roberta", "roberta-base",
#         # "bert", "bert-base-uncased",
#         num_labels=num_labels,
#         args=model_args,
#         use_cuda=torch.cuda.is_available()
#     )

#     # Train the model
#     model.train_model(df_train)

#     # # Evaluate the model
#     # result, model_outputs, wrong_predictions = model.eval_model(test_df, acc=accuracy_score)
#     # # Return the evaluation metric to optimize
#     # return result['acc']

#     # Evaluate the model
#     result, model_outputs, wrong_predictions = model.eval_model(df_test)

#     # Calculate additional metrics
#     y_pred = model_outputs.argmax(axis=1)
#     f1 = f1_score(y_test, y_pred, average='weighted')

#     # Return the F1-score to optimize
#     return f1

# # Create a study object and optimize the objective function
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=40)

# # Print the best hyperparameters and the best accuracy
# print('Best hyperparameters:', study.best_params)
# print('Best f1:', study.best_value)

# %% [markdown]
# # Final Model Training + Evaluation

# %%
model_args = ClassificationArgs()

model_args.num_train_epochs = 5
model_args.learning_rate = 8.521786512851659e-05
model_args.train_batch_size = 8
model_args.eval_batch_size = 24
model_args.max_seq_length = 512

model_args.output_dir = "outputs/"
model_args.overwrite_output_dir = True

# %%
# Create a ClassificationModel
model = ClassificationModel(
    "roberta", "roberta-base",
    # "bert", "bert-base-uncased",
    num_labels=num_labels,  # Number of labels
    args=model_args,
    use_cuda=use_cuda
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# Train the model
model.train_model(df_train[['text', 'label']])
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/classification/classification_model.py:610: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 0it [00:00, ?it/s]
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Running Epoch 1 of 5:   0%|          | 0/24 [00:00<?, ?it/s]
# Running Epoch 2 of 5:   0%|          | 0/24 [00:00<?, ?it/s]
# Running Epoch 3 of 5:   0%|          | 0/24 [00:00<?, ?it/s]
# Running Epoch 4 of 5:   0%|          | 0/24 [00:00<?, ?it/s]
# Running Epoch 5 of 5:   0%|          | 0/24 [00:00<?, ?it/s]
# (120, 0.8786977683504422)

# %%
# Evaluate the model
result, model_outputs, wrong_predictions = model.eval_model(df_test[['text', 'label']])
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/classification/classification_model.py:1453: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 0it [00:00, ?it/s]
# Running Evaluation:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Convert model outputs to predictions
predictions = model_outputs.argmax(axis=1)

# Print classification report
print(classification_report(y_test, predictions, target_names=label_mapping.keys()))

# Create a directory to save the results
os.makedirs('results', exist_ok=True)

# Save classification report to a text file
report = classification_report(y_test, predictions, target_names=label_mapping.keys())
with open('results/classification_report.txt', 'w') as f:
    f.write(report)

# # Save hyperparameters to a JSON file
# with open('results/best_hyperparameters.json', 'w') as f:
#     json.dump(study.best_params, f, indent=4)

model_args_dict = {
    'learning_rate': model_args.learning_rate,
    'num_train_epochs': model_args.num_train_epochs,
    'train_batch_size': model_args.train_batch_size,
    'eval_batch_size': model_args.eval_batch_size,
    'max_seq_length': model_args.max_seq_length,
}

# Save hyperparameters to a JSON file
with open('results/model_args.json', 'w') as f:
    json.dump(model_args_dict, f, indent=4)

# Compute confusion matrix
cm = confusion_matrix(y_test, predictions)

# Convert confusion matrix to DataFrame for better label handling
cm_df = pd.DataFrame(cm, index=label_mapping.keys(), columns=label_mapping.keys())

# Plot confusion matrix
sns.set(context="paper", font_scale=1.7)
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')

# Save the confusion matrix plot
plt.savefig('results/confusion_matrix.png', format='png', bbox_inches='tight')
plt.savefig('results/confusion_matrix.pdf', format='pdf', bbox_inches='tight')

plt.show()
# Out:
#               precision    recall  f1-score   support
#
#       action       0.67      0.46      0.55        13
#    intention       0.61      0.76      0.68        25
#       belief       0.43      0.45      0.44        20
#    situation       0.77      0.62      0.69        16
#
#     accuracy                           0.59        74
#    macro avg       0.62      0.57      0.59        74
# weighted avg       0.61      0.59      0.59        74
